# %% [markdown]
# # Load the results

# %%
import bilby
import matplotlib.pyplot as plt

# %%
# Load from the output directory
result = bilby.result.read_in_result("data/08_reporting/linear_regression_result.json")

# Inspect parameters and evidence
print(result.parameter_labels)
print(result.log_evidence)
# Out:
# ['m', 'c']
# -253.11325230900016

# %%
# Standard corner plot of all posteriors
result.plot_corner()

# %%
posterior = result.posterior

# Plot histograms for each parameter
posterior.hist(bins=30, figsize=(10, 5))
plt.tight_layout()
plt.show()
